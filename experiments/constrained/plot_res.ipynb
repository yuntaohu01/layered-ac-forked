# %%
# %load_ext autoreload
# %autoreload 2

# %%
import plot_ss
import matplotlib.pyplot as plt
# Out:
# 2024-04-22 16:00:24.207703: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-22 16:00:24.722290: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## With Dual

# %%
base_logdir = 'with_new/'
keys = [
    'charts/val_rel_ret',
    'charts/val_rx_diff',
    'charts/val_constr_vio'
]
dat = plot_ss.gather_data(base_logdir, keys)
# Out:
# path exists
# path exists
# path exists
# path exists
# path exists
# path exists
# path exists
# path exists
# path exists

# %%
key = 'charts/val_rel_ret'
plot_ss.plot(dat[key], 'N')
plt.ylim([0.8, 5])
plt.title('Relative Return vs Optimal Controller')
# Out:
# 1.0185011625289917 19975.0
# Text(0.5, 1.0, 'Relative Return vs Optimal Controller')

# %%
key = 'charts/val_rx_diff'
plot_ss.plot(dat[key], 'N')
plt.yscale('log')
plt.title('Mean Deviation from Reference')
# Out:
# 0.006638737395405769 19975.0
# Text(0.5, 1.0, 'Mean Deviation from Reference')

# %%
key = 'charts/val_constr_vio'
plot_ss.plot(dat[key], 'N')
plt.yscale('log')
plt.title('Mean Deviation from Reference')
# Out:
# 1.3999920156493317e-05 19975.0
# Text(0.5, 1.0, 'Mean Deviation from Reference')

# %% [markdown]
# ## Without Dual Learning

# %%
base_logdir = 'wo_new/'
keys = [
    'charts/val_rel_ret',
    'charts/val_rx_diff',
    'charts/val_constr_vio'
]
dat = plot_ss.gather_data(base_logdir, keys)
# Out:
# path exists
# path exists
# path exists
# path exists
# path exists
# path exists
# path exists
# path exists
# path exists

# %%
key = 'charts/val_rel_ret'
plot_ss.plot(dat[key], 'rho')
plt.ylim([0.95, 3])
plt.title('Relative Return vs Optimal Controller')
# Out:
# 1.0129164457321167 19975.0
# Text(0.5, 1.0, 'Relative Return vs Optimal Controller')

# %%
key = 'charts/val_rx_diff'
plot_ss.plot(dat[key], 'rho')
plt.yscale('log')
plt.title('Mean Deviation from Reference')
# Out:
# 0.03739970177412033 19975.0
# Text(0.5, 1.0, 'Mean Deviation from Reference')

# %%
key = 'charts/val_constr_vio'
plot_ss.plot(dat[key], 'N')
plt.yscale('log')
plt.title('Mean Constraint Violation')
# Out:
# 0.00016808575310278684 19975.0
# Text(0.5, 1.0, 'Mean Constraint Violation')
